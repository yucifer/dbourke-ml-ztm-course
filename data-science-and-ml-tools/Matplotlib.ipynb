# %% [markdown]
# # Matplotlib 📊

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Let's plot empty plot. We are going to use pyplot API way of plotting which is less flexible than Object Oriented API.
plt.plot()
# Out:
# []

# %%
# Let's get rid of that []
plt.plot();

# %%
# Another way to do so is
plt.plot()
plt.show()

# %%
# Let's plot x-axes data.
plt.plot([1,2,3,4,5]);

# %%
x = [1,2,3,4]
y = [11,22,33,44]
plt.plot(x,y);

# %%
# We will focus on the Object Oriented API which is the recommended way of plotting.
# 1st Method
fig = plt.figure() # creates a figure
axes = fig.add_subplot() # adds some axes
plt.show()

# %%
# 2nd Method
fig = plt.figure() # creates a figure
ax = fig.add_axes([1,1,1,1])
ax.plot(x,y) # add some data
plt.show()

# %%
# 3rd method (recommended way)
fig, ax = plt.subplots()
ax.plot(x,y)
plt.show()

# %% [markdown]
# ## Matplotlib example workflow

# %%
# 0. import matplotlib and get it ready for plotting in jupyter notebook
# %matplotlib inline
import matplotlib.pyplot as plt

# 1. Prepare Data
x = [10,20,30,40]
y = [30,60,90,120]

# 2. Setup Plot
fig, ax = plt.subplots(figsize=(5,5)) # (width, height)

# 3. Plot Data
ax.plot(x,y)

# 4. Customize Plot
ax.set(title="Sample Plot",
      xlabel="x-axis",
      ylabel="y-axis")

# 5. Save & Show (you save the whole figure)
plt.savefig("images/sample-plot.png")

# %% [markdown]
# ## Making figures with NumPy arrays
#
# We will focus on basic plots like :
# * Line
# * Scatter
# * Bar
# * Histogram
# * Subplots

# %%
# create some data 
x = np.linspace(0,10,100)

# %%
# Plot the Data and create a line plot (line plot is default)
fig, ax = plt.subplots()
ax.plot(x, x**2)
plt.show()

# %%
# Use same data to make scatter plot
fig, ax = plt.subplots(figsize=(10,10))
ax.scatter(x,np.exp(x))
plt.show()

# %%
# Another scatter plot
fig, ax = plt.subplots()
ax.scatter(x,np.sin(x))
plt.show()

# %%
# Make a plot from dictionary
nut_butter_prices = {"Almond": 10,
                   "Peanut": 8,
                   "Cashew": 15}
fix , ax = plt.subplots()
ax.bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax.set(title="Yash's Nut Butter Store", xlabel="Butter Type", ylabel="Price")
plt.show()

# %%
# Horizontal bar graph
fig, ax = plt.subplots()
ax.barh(list(nut_butter_prices.keys()), nut_butter_prices.values());

# %%
# Histogram 
x = np.random.randn(1000)
fig, ax = plt.subplots()
ax.hist(x);

# %% [markdown]
# ### Plotting Subplots
#
# There are two options for plotting subplots.

# %%
# 1st option
x = [1,2,3,4]
y = [11,22,33,44]
fig, ((ax0,ax1), (ax2,ax3)) = plt.subplots(nrows=2, ncols=2, figsize=(10,5))

# Plot to each different axis
ax0.plot(x,y)
ax1.scatter(np.random.random(10), np.random.random(10))
ax2.bar(nut_butter_prices.keys(),nut_butter_prices.values())
ax3.hist(np.random.randn(1000));

# %%
# 2nd option 
x = np.random.random(10)
fig, ax = plt.subplots(nrows=2,ncols=2,figsize=(10,5))

# Plot to different index
ax[0,0].plot(x,x/2)
ax[0,1].scatter(np.random.random(10),np.random.random(10))
ax[1,0].barh(list(nut_butter_prices.keys()), nut_butter_prices.values())
ax[1,1].hist(np.random.randn(1000));

# %% [markdown]
# ### Plotting from Pandas Dataframe

# %%
import pandas as pd

# %%
# Make a DataFrame
car_sales = pd.read_csv("car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# An Example that demonstrates that under the hood pandas uses matplotlib for plotting.
ts = pd.Series(np.arange(1,11,1))
ts = ts.cumsum()
ts.plot()
# Out:
# <AxesSubplot:>

# %%
# Another example
ts1 = pd.Series(np.random.randn(1000),
               index=pd.date_range("1/1/2021",periods=1000))
ts1 = ts1.cumsum()
ts1.plot()
# Out:
# <AxesSubplot:>

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# Using regex to strip the $ sign, the comma , and the decimal . in the Price column
car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]','')
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
type(car_sales["Price"][0])
# Out:
# str

# %%
# Remove the trailing 2 zeros from the Price column
car_sales["Price"] = car_sales["Price"].str[:-2]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
# Add the Sales Date column using date_range
car_sales["Sales Date"] = pd.date_range(start="1/1/2021", periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price Sales Date
# 0  Toyota  White         150043      4   4000 2021-01-01
# 1   Honda    Red          87899      4   5000 2021-01-02
# 2  Toyota   Blue          32549      3   7000 2021-01-03
# 3     BMW  Black          11179      5  22000 2021-01-04
# 4  Nissan  White         213095      4   3500 2021-01-05
# 5  Toyota  Green          99213      4   4500 2021-01-06
# 6   Honda   Blue          45698      4   7500 2021-01-07
# 7   Honda   Blue          54738      4   7000 2021-01-08
# 8  Toyota  White          60000      4   6250 2021-01-09
# 9  Nissan  White          31600      4   9700 2021-01-10

# %%
# Add the Total Sales column which cummulates the Total money earned from selling after each day
# Remember to convert the Price column dtype as numeric
car_sales["Total Sales"] = car_sales["Price"].astype(int).cumsum()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price Sales Date  Total Sales
# 0  Toyota  White         150043      4   4000 2021-01-01         4000
# 1   Honda    Red          87899      4   5000 2021-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2021-01-03        16000
# 3     BMW  Black          11179      5  22000 2021-01-04        38000
# 4  Nissan  White         213095      4   3500 2021-01-05        41500
# 5  Toyota  Green          99213      4   4500 2021-01-06        46000
# 6   Honda   Blue          45698      4   7500 2021-01-07        53500
# 7   Honda   Blue          54738      4   7000 2021-01-08        60500
# 8  Toyota  White          60000      4   6250 2021-01-09        66750
# 9  Nissan  White          31600      4   9700 2021-01-10        76450

# %%
# Let's plot Sales Date v/s Total Sales 
car_sales.plot(x="Sales Date", y="Total Sales");

# %%
# Let's plot a scatter plot of Odometer (KM) v/s Price

# Let's first convert the Price column's dtype as int
car_sales["Price"] = car_sales["Price"].astype(int)

# Let's plot the scatter plot now
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter");

# %%
car_sales["Doors"].dtype
# Out:
# dtype('int64')

# %%
# Let's try to plot the Histogram for the Doors column
car_sales["Doors"].plot(kind="hist").set(xlabel="Doors");

# %%
# Let's plot a bar graph
sample_data = pd.DataFrame(np.random.rand(10,4),columns=list("abcd"))
sample_data
# Out:
#           a         b         c         d
# 0  0.226822  0.053739  0.647171  0.872244
# 1  0.996833  0.628877  0.149491  0.609208
# 2  0.808272  0.484334  0.578329  0.594184
# 3  0.296002  0.648492  0.432335  0.520282
# 4  0.714376  0.824544  0.920095  0.722942
# 5  0.073936  0.865088  0.369910  0.227770
# 6  0.263250  0.955560  0.827703  0.721021
# 7  0.413673  0.725236  0.100317  0.977810
# 8  0.627360  0.724037  0.978309  0.545783
# 9  0.278694  0.403716  0.496116  0.008490

# %%
# Let's plot 
sample_data.plot.bar();

# %%
# One more example 
sample_data2 = pd.DataFrame(np.random.randn(10,4),columns=list("efgh"))
sample_data2
# Out:
#           e         f         g         h
# 0 -0.069154 -0.033456  0.105671 -0.596676
# 1  1.133855  0.372668  0.758944 -0.792737
# 2  1.204837 -0.247749 -0.614115  0.384203
# 3 -1.068132 -1.378912  1.270324 -0.250651
# 4  0.784907 -0.488359  1.772648 -1.258078
# 5 -0.924298 -0.293849 -1.239735 -1.404171
# 6 -0.605847 -1.918433  0.286087 -0.443673
# 7  0.140762  0.950859  0.077186 -0.016591
# 8 -0.882450 -2.029558  0.058981  0.714064
# 9 -0.935778 -0.717569 -0.191490  1.193387

# %%
sample_data2.plot(kind="bar");

# %%
# Let's plot the bar graph for the Make v/s Odometer (KM) column for our car sales data.
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price Sales Date  Total Sales
# 0  Toyota  White         150043      4   4000 2021-01-01         4000
# 1   Honda    Red          87899      4   5000 2021-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2021-01-03        16000
# 3     BMW  Black          11179      5  22000 2021-01-04        38000
# 4  Nissan  White         213095      4   3500 2021-01-05        41500
# 5  Toyota  Green          99213      4   4500 2021-01-06        46000
# 6   Honda   Blue          45698      4   7500 2021-01-07        53500
# 7   Honda   Blue          54738      4   7000 2021-01-08        60500
# 8  Toyota  White          60000      4   6250 2021-01-09        66750
# 9  Nissan  White          31600      4   9700 2021-01-10        76450

# %%
car_sales.plot(x="Make", y="Odometer (KM)", kind="bar");

# %%
# Let's plot a Histogram again for Odomter (KM) column
car_sales["Odometer (KM)"].plot.hist(bins=10);

# %%
# Let's try on another dataset
heart_disease = pd.read_csv("heart-disease.csv")
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
# Create a Histogram to see the distribution of the age column
heart_disease["age"].plot.hist(bins=10);

# %%
# Let's try to plot the histogram for every column as a subplots to get better understanding of data distribution.
heart_disease.plot.hist(subplots=True,bins=100);

# %%
# Looks like there is a bit of overlap in order to fix this
heart_disease.plot.hist(figsize=(10,30),subplots=True,bins=100);

# %%
heart_disease.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %% [markdown]
# ####  All the above plots which we plotted using the Pandas Object were using the pyplot API (stateless) under the hood.

# %% [markdown]
# ### Which one to use ? (pyplot API vs Matplotlib OO API) ?
# * When it comes to plotting something quickly, it is okay to use pyplot API.
# * When it comes to plotting something more advanced use the matplotlib Object Oriented API.

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
# Let's now plot using the OO API
# First we will create a subset of our data so we can do some data analysis as well.
over_50 = heart_disease.loc[heart_disease["age"] > 50] # we can also use heart_disease.loc[heart_disease["age"] > 50]
over_50
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   59    1   0       164   176    1        0       90      0      1.0
# 298   57    0   0       140   241    0        1      123      1      0.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 3        2   0     2       1
# ...

# %%
# Let's try to plot a scatter plot of age v/s chol and target by using the pyplot API
over_50.plot(kind="scatter", 
            x="age",
            y="chol",
            c="target"); # 'c' stands for color. Here we want to use the color according to target column

# %%
# Now it doesn't kinda looks good. Let's replot it using the OO method mixed with pyplot method.
fig, ax = plt.subplots(figsize=(10,6))
over_50.plot(kind="scatter",
            x="age",
            y="chol",
            c="target",
            ax=ax)

# Let's make it wider 
ax.set_xlim([45,100]);

# %%
# Let's plot it using OO method from scratch
fig, ax = plt.subplots(figsize=(10,6))

# Plot the data
scatter = ax.scatter(x=over_50["age"],
                    y=over_50["chol"],
                    c=over_50["target"])

# Customize the Plot
ax.set(title="Heart Disease and Cholestrol Levels",
      xlabel="Age",
      ylabel="Cholestrol")

# Add a legend
ax.legend(*scatter.legend_elements(), title="Target")

# Add a horizontal line at the mean cholestrol level
ax.axhline(y=over_50["chol"].mean(),linestyle='--',color="red");

# %%
# Subplot of chol, thalach, age
fig, (ax0, ax1) = plt.subplots(nrows=2,
                              ncols=1,
                              figsize=(10,10),
                              sharex=True)

# Add data to ax0
scatter = ax0.scatter(x=over_50["age"],
                     y=over_50["chol"],
                     c=over_50["target"])

# Customize ax0
ax0.set(title="Heart Disease and Cholestrol Levels", ylabel="Cholestrol")

# Add a legend in ax0
ax0.legend(*scatter.legend_elements(), title="Target")

# Add a horixontal line indicating the mean cholestrol level
ax0.axhline(y=over_50.chol.mean(), linestyle='--')

# Add data to ax1
scatter = ax1.scatter(x=over_50["age"],
                     y=over_50["thalach"],
                     c=over_50["target"])

# Customize ax1
ax1.set(title="Heart Disease and Max Heart Rate", xlabel="Age", ylabel="Max Heart Rate")

# Add a legend in ax1
ax1.legend(*scatter.legend_elements(), title="Target")

# Add a horixontal line indicating the mean max heart rate level
ax1.axhline(y=over_50.thalach.mean(),linestyle='--');

# Add a title to the figure
fig.suptitle("Heart Disease Analysis", fontsize=16, fontweight='bold');

# %% [markdown]
# ## Customising the Matplotlib plots and getting stylish

# %%
# See the different styles available
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors  Price Sales Date  Total Sales
# 0  Toyota  White         150043      4   4000 2021-01-01         4000
# 1   Honda    Red          87899      4   5000 2021-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2021-01-03        16000
# 3     BMW  Black          11179      5  22000 2021-01-04        38000
# 4  Nissan  White         213095      4   3500 2021-01-05        41500

# %%
car_sales["Price"].plot();

# %%
plt.style.use('seaborn')

# %%
car_sales["Price"].plot();

# %%
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter");

# %%
plt.style.use('ggplot')

# %%
car_sales["Price"].plot();

# %%
# Create some data
x = pd.DataFrame(np.random.randn(10,4), columns=list("abcd"))
x
# Out:
#           a         b         c         d
# 0  0.119487 -0.318807 -1.206109 -1.163162
# 1  2.095422  0.777045  1.265464 -0.321417
# 2  0.020031  0.666506  0.708054  0.488386
# 3 -0.119470  0.326611  0.939063  1.182607
# 4  0.363523 -0.166863 -2.274679  0.755312
# 5  1.067074 -0.863424  0.284017  0.356180
# 6  0.385394 -0.306393 -1.541259  0.291980
# 7  0.075390  1.751739  1.130318 -0.707676
# 8  0.105344  1.072002 -0.117642  0.422417
# 9 -1.299289  0.293389  0.018304  1.403719

# %%
ax = x.plot(kind="bar")
ax;

# %%
# Customize our plot with the set() method
ax = x.plot(kind="bar")

# Add some labels and a title
ax.set(title="Random Number Bar Chart from DataFrame", 
      xlabel="Row Number",
      ylabel="Random Number");

# Make legend visible if it is not visible
ax.legend().set_visible(True)

# %%
# Set the style of the plot
plt.style.use('seaborn-whitegrid')

# Subplot of chol, thalach, age
fig, (ax0, ax1) = plt.subplots(nrows=2,
                              ncols=1,
                              figsize=(10,10),
                              sharex=True)

# Add data to ax0
scatter = ax0.scatter(x=over_50["age"],
                     y=over_50["chol"],
                     c=over_50["target"],
                     cmap='winter')  # cmap stands for 'color map'

# Customize ax0
ax0.set(title="Heart Disease and Cholestrol Levels", ylabel="Cholestrol")

# Set ax0 x_limit
ax0.set_xlim([50,80])

# Add a legend in ax0
ax0.legend(*scatter.legend_elements(), title="Target")

# Add a horixontal line indicating the mean cholestrol level
ax0.axhline(y=over_50.chol.mean(), linestyle='--',color='red')

# Add data to ax1
scatter = ax1.scatter(x=over_50["age"],
                     y=over_50["thalach"],
                     c=over_50["target"],
                     cmap='winter')

# Customize ax1
ax1.set(title="Heart Disease and Max Heart Rate", xlabel="Age", ylabel="Max Heart Rate")

# Set ax1 x_limit and y_limit
ax1.set_xlim([50,80])
ax1.set_ylim([60,200])

# Add a legend in ax1
ax1.legend(*scatter.legend_elements(), title="Target")

# Add a horixontal line indicating the mean max heart rate level
ax1.axhline(y=over_50.thalach.mean(),linestyle='--',color='red');

# Add a title to the figure
fig.suptitle("Heart Disease Analysis", fontsize=16, fontweight='bold');

# %%
fig.savefig('heart-disease-analysis-plot.png')
